# %%
import pandas as pd

# %%
df = pd.read_csv("merged.csv")

# %%
print(df.head(10))
# Out:
#               author                       date  \
# 0  Expertdeadlygamer  2021-04-30 18:24:06+00:00
# 1       crazyfortaco  2021-04-30 18:16:05+00:00
# 2         shirokan__  2021-04-30 18:15:07+00:00
# 3         TrentRizzo  2021-04-30 18:04:33+00:00
# 4            Phil_82  2021-04-30 18:03:07+00:00
# 5          traverlaw  2021-04-30 17:55:51+00:00
# 6          MoffrowMs  2021-04-30 17:54:40+00:00
# 7     That-Card-9837  2021-04-30 17:52:09+00:00
# 8       DeMonstratio  2021-04-30 17:47:38+00:00
# 9     Zetafunction64  2021-04-30 17:39:30+00:00
#
#                                                title  \
# 0       My daughter wanted her body painted by Chalk
# 1  The longest drum solo was 10 hours and 26 minu...
# 2   Did you hear about the claustrophobic astronaut?
# 3                                       Breaking bad
# 4  A wife waits outside the doctors office while ...
# 5                                    Lauren Boebert?
# 6   What's the difference between a man and a woman?
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                    author                       date  \
# 0       Expertdeadlygamer  2021-04-30 18:24:06+00:00
# 1            crazyfortaco  2021-04-30 18:16:05+00:00
# 2              shirokan__  2021-04-30 18:15:07+00:00
# 3              TrentRizzo  2021-04-30 18:04:33+00:00
# 4                 Phil_82  2021-04-30 18:03:07+00:00
# ...                   ...                        ...
# 5452  ValuableTrouble8825  2020-12-19 18:55:26+00:00
# 5453           68smulcahy  2020-12-19 15:46:12+00:00
# 5454            [deleted]  2020-12-18 22:44:51+00:00
# 5455            retsofyma  2020-12-18 22:06:33+00:00
# 5456       baldArtTeacher  2020-12-18 21:02:12+00:00
#
#                                                   title  \
# 0          My daughter wanted her body painted by Chalk
# 1     The longest drum solo was 10 hours and 26 minu...
# 2      Did you hear about the claustrophobic astronaut?
# 3                                          Breaking bad
# ...

# %%
df.to_csv("marged.csv")

# %%
import pandas as pd

# %%
df = pd.read_csv("F:\Jupyter Notebooks\Solution Challenge\Schizophrenia Detection\SchiDetect\SchiDetect\spiders\Scraping\\meditation.csv")

# %%
df
# Out:
#      Unnamed: 0             author                       date  \
# 0             0        folklorecth  2022-02-04 11:56:07+00:00
# 1             1             zihua_  2022-02-04 11:11:17+00:00
# 2             2       wonggloria99  2022-02-04 09:54:38+00:00
# 3             3          logett112  2022-02-04 09:05:15+00:00
# 4             4   STUCKinsideAwall  2022-02-04 08:56:35+00:00
# ..          ...                ...                        ...
# 994         995           Daen1337  2022-01-18 19:36:20+00:00
# 995         996       beeberryxoxo  2022-01-18 19:23:53+00:00
# 996         997      Seitenbrenner  2022-01-18 19:06:14+00:00
# 997         998         Cyrilavery  2022-01-18 19:01:11+00:00
# 998         999  Intelligent_Vibes  2022-01-18 18:09:58+00:00
#
#                                                  title  \
# 0                             Amazing Meditation Video
# 1              Why should one meditate? | Kirshnamurti
# ...

# %%
df.dropna(inplace = True)

# %%
idx = df[df['selftext']=='[removed]'].index

# %%
df.drop(idx, inplace = True)

# %%
df
# Out:
#      Unnamed: 0            author                       date  \
# 2             2      wonggloria99  2022-02-04 09:54:38+00:00
# 4             4  STUCKinsideAwall  2022-02-04 08:56:35+00:00
# 5             5        kenshin_16  2022-02-04 08:38:35+00:00
# 9             9    lavendermoon27  2022-02-04 04:48:13+00:00
# 10           10        thinkcleer  2022-02-04 04:12:02+00:00
# ..          ...               ...                        ...
# 990         991         yakboxing  2022-01-18 21:01:46+00:00
# 991         992       TheLifeOfAz  2022-01-18 20:24:20+00:00
# 992         993        silentj420  2022-01-18 20:12:27+00:00
# 994         995          Daen1337  2022-01-18 19:36:20+00:00
# 996         997     Seitenbrenner  2022-01-18 19:06:14+00:00
#
#                                                  title  \
# 2    Anybody also start to do things much slower af...
# 4                     How can good feelings feel good?
# 5        Is my solar plexus and heart chakra blocked ?
# ...

# %%
df.reset_index(inplace = True)

# %%
df.to_csv('meditation.csv')

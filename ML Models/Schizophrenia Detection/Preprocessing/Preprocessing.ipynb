# %%
import re
import numpy as np
import pandas as pd
import preprocess_kgptalkie as ps

# %%
df = pd.read_csv("control.csv")

# %%
df = df.drop("text", axis=1)

# %%
df
# Out:
#                    author                       date  \
# 0       Expertdeadlygamer  2021-04-30 18:24:06+00:00
# 1            crazyfortaco  2021-04-30 18:16:05+00:00
# 2              shirokan__  2021-04-30 18:15:07+00:00
# 3              TrentRizzo  2021-04-30 18:04:33+00:00
# 4                 Phil_82  2021-04-30 18:03:07+00:00
# ...                   ...                        ...
# 5448  ValuableTrouble8825  2020-12-19 18:55:26+00:00
# 5449           68smulcahy  2020-12-19 15:46:12+00:00
# 5450            [deleted]  2020-12-18 22:44:51+00:00
# 5451            retsofyma  2020-12-18 22:06:33+00:00
# 5452       baldArtTeacher  2020-12-18 21:02:12+00:00
#
#                                                   title  \
# 0          my daughter wanted her body painted by chalk
# 1     the longest drum solo was 10 hours and 26 minutes
# 2       did you hear about the claustrophobic astronaut
# 3                                          breaking bad
# 4     a wife waits outside the doctors office while ...
# ...                                                 ...
# 5448                         i want to become a teacher
# 5449                                      abcs of covid
# 5450     lesson plan sustainability is a societal issue
# 5451                     looking for advice uk teachers
# 5452  i have been putting in for accomidations to wo...
#
#                                                selftext  \
# 0                               she said chalk me daddy
# 1     and it was performed by the child sitting behi...
# 2                         he just needed a little space
# 3     i was talking to someone about breaking bad an...
# 4     wife honey whats wronghusband the doc told me ...
# ...                                                 ...
# 5448  i want to become a psychology teacher in a mid...
# 5449  highly recommend showing the the abcs of covid...
# 5450                                            deleted
# 5451  just wanted to ask for some advice i am lookin...
# 5452  my school has been open full time in person al...
#
#                                                    text  label
# 0     my daughter wanted her body painted by chalk s...      0
# 1     the longest drum solo was 10 hours and 26 minu...      0
# 2     did you hear about the claustrophobic astronau...      0
# 3     breaking bad i was talking to someone about br...      0
# 4     a wife waits outside the doctors office while ...      0
# ...                                                 ...    ...
# 5448  i want to become a teacher i want to become a ...      0
# 5449  abcs of covid highly recommend showing the the...      0
# 5450  lesson plan sustainability is a societal issue...      0
# 5451  looking for advice uk teachers just wanted to ...      0
# 5452  i have been putting in for accomidations to wo...      0
#
# [5453 rows x 6 columns]

# %%
def get_clean(x):
    x = str(x).lower().replace('\\', '').replace('_', ' ')
    x = ps.cont_exp(x)
    x = ps.remove_emails(x)
    x = ps.remove_urls(x)
    x = ps.remove_html_tags(x)
    x = ps.remove_rt(x)
    x = ps.remove_accented_chars(x)
    x = ps.remove_special_chars(x)
    x = re.sub("(.)\\1{2,}", "\\1", x)
    return x

# %%
df['title'] = df['title'].apply(lambda x: get_clean(x))

# %%
df['selftext'] = df['selftext'].apply(lambda x: get_clean(x))

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#                    author                       date  \
# 0       Expertdeadlygamer  2021-04-30 18:24:06+00:00
# 1            crazyfortaco  2021-04-30 18:16:05+00:00
# 2              shirokan__  2021-04-30 18:15:07+00:00
# 3              TrentRizzo  2021-04-30 18:04:33+00:00
# 4                 Phil_82  2021-04-30 18:03:07+00:00
# ...                   ...                        ...
# 5448  ValuableTrouble8825  2020-12-19 18:55:26+00:00
# 5449           68smulcahy  2020-12-19 15:46:12+00:00
# 5450            [deleted]  2020-12-18 22:44:51+00:00
# 5451            retsofyma  2020-12-18 22:06:33+00:00
# 5452       baldArtTeacher  2020-12-18 21:02:12+00:00
#
#                                                   title  \
# 0          my daughter wanted her body painted by chalk
# 1     the longest drum solo was 10 hours and 26 minutes
# 2       did you hear about the claustrophobic astronaut
# 3                                          breaking bad
# 4     a wife waits outside the doctors office while ...
# ...                                                 ...
# 5448                         i want to become a teacher
# 5449                                      abcs of covid
# 5450     lesson plan sustainability is a societal issue
# 5451                     looking for advice uk teachers
# 5452  i have been putting in for accomidations to wo...
#
#                                                selftext  \
# 0                               she said chalk me daddy
# 1     and it was performed by the child sitting behi...
# 2                         he just needed a little space
# 3     i was talking to someone about breaking bad an...
# 4     wife honey whats wronghusband the doc told me ...
# ...                                                 ...
# 5448  i want to become a psychology teacher in a mid...
# 5449  highly recommend showing the the abcs of covid...
# 5450                                            deleted
# 5451  just wanted to ask for some advice i am lookin...
# 5452  my school has been open full time in person al...
#
#                                                    text  label
# 0     my daughter wanted her body painted by chalk s...      0
# 1     the longest drum solo was 10 hours and 26 minu...      0
# 2     did you hear about the claustrophobic astronau...      0
# 3     breaking bad i was talking to someone about br...      0
# 4     a wife waits outside the doctors office while ...      0
# ...                                                 ...    ...
# 5448  i want to become a teacher i want to become a ...      0
# 5449  abcs of covid highly recommend showing the the...      0
# 5450  lesson plan sustainability is a societal issue...      0
# 5451  looking for advice uk teachers just wanted to ...      0
# 5452  i have been putting in for accomidations to wo...      0
#
# [5368 rows x 6 columns]

# %%
df.to_csv("control.csv")

# %%
df["text"] = df["title"]+" "+df["selftext"]

# %%
df
# Out:
#                    author                       date  \
# 0       Expertdeadlygamer  2021-04-30 18:24:06+00:00
# 1            crazyfortaco  2021-04-30 18:16:05+00:00
# 2              shirokan__  2021-04-30 18:15:07+00:00
# 3              TrentRizzo  2021-04-30 18:04:33+00:00
# 4                 Phil_82  2021-04-30 18:03:07+00:00
# ...                   ...                        ...
# 5448  ValuableTrouble8825  2020-12-19 18:55:26+00:00
# 5449           68smulcahy  2020-12-19 15:46:12+00:00
# 5450            [deleted]  2020-12-18 22:44:51+00:00
# 5451            retsofyma  2020-12-18 22:06:33+00:00
# 5452       baldArtTeacher  2020-12-18 21:02:12+00:00
#
#                                                   title  \
# 0          my daughter wanted her body painted by chalk
# 1     the longest drum solo was 10 hours and 26 minutes
# 2       did you hear about the claustrophobic astronaut
# 3                                          breaking bad
# 4     a wife waits outside the doctors office while ...
# ...                                                 ...
# 5448                         i want to become a teacher
# 5449                                      abcs of covid
# 5450     lesson plan sustainability is a societal issue
# 5451                     looking for advice uk teachers
# 5452  i have been putting in for accomidations to wo...
#
#                                                selftext  \
# 0                               she said chalk me daddy
# 1     and it was performed by the child sitting behi...
# 2                         he just needed a little space
# 3     i was talking to someone about breaking bad an...
# 4     wife honey whats wronghusband the doc told me ...
# ...                                                 ...
# 5448  i want to become a psychology teacher in a mid...
# 5449  highly recommend showing the the abcs of covid...
# 5450                                            deleted
# 5451  just wanted to ask for some advice i am lookin...
# 5452  my school has been open full time in person al...
#
#                                                    text  label
# 0     my daughter wanted her body painted by chalk s...      0
# 1     the longest drum solo was 10 hours and 26 minu...      0
# 2     did you hear about the claustrophobic astronau...      0
# 3     breaking bad i was talking to someone about br...      0
# 4     a wife waits outside the doctors office while ...      0
# ...                                                 ...    ...
# 5448  i want to become a teacher i want to become a ...      0
# 5449  abcs of covid highly recommend showing the the...      0
# 5450  lesson plan sustainability is a societal issue...      0
# 5451  looking for advice uk teachers just wanted to ...      0
# 5452  i have been putting in for accomidations to wo...      0
#
# [5368 rows x 6 columns]
